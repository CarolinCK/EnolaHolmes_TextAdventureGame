# %%
## The story of the game is based on the Netflix movie Enola Holmes, 2020##
# The ideas for the games come from Prof. Chase Kusterer and Al Sweigart # 

#importing the functions that are necessary for the upcoming games
import random, time

def escape_1():
    """During escape_1 Enola takes the train to London and meets Tewkesbury."""

    #Background information and story for the adventure game
    print (""" 

    United Kingdom, 1900
    This is your story,
    the story of Enola Holmes, the sister of Sherlock Holmes.
    You are 15 years younger than Sherlock and only grew up with your mother.
    She raised you to be an independent woman, able to decipher, do jiujitsu,
    and just like Sherlock, solve mysteries.
    On your 16th birthday you find out that you were left by your mother.
    Your brothers are trying to send you to a boarding school.
    A school meant for you to be turned into the perfect wife.
    However, you don't agree with their plans and escape. 
    
    """)
    #Prompting user on whether they want to play the game or not 
    start=input(prompt= "Do you want to go on this journey? (Yes/No): ")
    
    #a print statement to increase readability for the user
    print()

    #Conditional statement to start the game when the user wants to play
    #Otherwise move to fail() function 
    if "yes" in start.lower().strip():

        #Prompting user to answer first question about Enolas escape
        print ("Enola you can either take your bike or the train to escape.")

        first_decision= input(prompt= "What do you choose? (Bike/Train): ")
        if "train" in first_decision.lower().strip():
            print ("Great, you successfully escaped and are on the train.\n")

            #Riddle to solve for the user
            s="London"
            decipher=''.join(random.sample(s,len(s)))
            print(f"On the train you meet Viscount Tewkesbury Marquess of Basilwether.\nYou challenge him to decipher your final destination:\n\n\t'{decipher}'")
            
            #a print statement to increase readability for the user
            print()
            first_meeting=input(prompt="What is the final destination?:  ") 
            #a print statement to increase readability for the user
            print()
            
            
            #Conditional statement to check whether the user solved the riddle 
            if "london" in first_meeting.lower().strip():
                print ("He was able to decipher your destination.\nYou decide that 'Tewkesbury' can join you until you make it to London.")

            else:
                print("That was wrong.\n However, you let 'Tewkesbury' stay until you make it to London.")
            
            #moving to escape_2
            return "continue"
        
        else:
            return fail()
            
                
    else:
        print ("Your escape attempt failed.\n")
        return fail()
    
def escape_2():
    """During escape_2 Enola is looking for the person to explain her why her mother left, and she is looking for Tewkesbury"""
     
    #Declaring objects for upcoming loops
    number = random.randint(1,5) # random number remains the same for each guess
    chances = 3
    #a print statement to increase readability for the user
    print()
    print("You made it to the second part of your journey")
    
    #Introduction to the next game, finding the right person 
    print("You and Tewkesbury successfully made it to London and your paths seperate.\nYou realize London is a very big and overwhelming city.\nYou are trying to find the right person to help you understand why your mother left.\n")

    #Loop for number guessing game that runs until the user runs out of chances
    #only integers between 1-5 count as a chance 
    while chances >0: 
        print ("""
        
        You have three attempts to find the right person. 
        Each number from 1 to 5 represents one person. 
        
        """)
        #Infinite loop until three guesses are successfully completed 
        while True:
            choice = input(prompt= "What is your guess (1-5)? ")

            # converting choice into an integer for numerical comparison
            if choice.isdigit() and int(choice) >0 and int(choice) <=5:
                break

            else:
                print("Invalid input please return an integer between 1 and 5")
                
                #a print statement to increase readability for the user
                print()

        #conditional statement based on user input
        choice = int(choice)
        if choice == number:
            print ("You were able to find the right person!")
            
            #a print statement to increase readability for the user
            print()
            print("You learn that your mother left you to be the leader of the female revolution.\nHowever, you have your own plan.")
            break

        elif choice != number:
            chances -=1

            #printing a message when there are still chances 
            if chances > 0: 
                print (f"That's incorrect, try again. You have {chances} guesses remaining")

            #printing a message when there are no chances left 
            elif chances ==0:
                    print (f"""I'm sorry you are out of chances 
                          The correct number was {number}.
                          Enola couldn't find who she was looking for""")
                    return fail()
            else:
                print("Invalid entry. Please try again.\n")
                escape_2()
        
        #checks whether something in the code is not functioning properly
        else:
            print("Something is wrong line:132")

    #Maze to find Tewksbury
    #Source: AsciiArt Maze 
    print ()
    print ("Find the path you need to take to find Tewkesbury.")
    print ("""
    ___________________________________  
    | _____ |   | ___ | ___ ___ | |   |  End: Tewkesbury
    | |   | |_| |__ |A|_| __|____ | | | |
    | | | |_________|__ |______ |___|_| |
    | |_|   | _______ |______ |   | ____|
    | ___ | |____B| |______ | |_| |____ |
    |___|_|____ | |   ___ | |________ | |
    |   ________| | |__ | |______ | | | |
    | | | ________| |C__|____ | | | __| |
    |_| |__ |   | __|__ | ____| | |_| __|
    |   ____| | |____ | |__ |   |__ |__ |
    | |_______|_______|___|___|___|_____|

    Start: Enola

    """)
    #While true loop to check the correctness of the answer and ensure the user is not trying to cheat
    while True:
        choosen_path=input(prompt="Input the letter of the path that Enola needs to take: ")

        if "ABC" in choosen_path.upper().strip() :
            print ("You loose, you were not able to find Tewkesbury!")
            return fail()
            break

        elif "A" and "B" and "C" in choosen_path.upper().strip():
            print ("Please only input the letter.")
            
        elif "B" in choosen_path.upper().strip() :
            print ("Great! You found Tewkesbury.")
            return "continue"
            break

        else: 
            print ("You loose, you were not able to find Tewkesbury!")
            return fail()
            break



def escape_3():
    """During escape_3 Enola is taking Tewkesbury to the House of Lords to vote, escaping the police."""

    #Source: Fast Draw, by Al Sweigert al@inventwithpython.com

    #Explaining the next game and the story behind it 
    print(""" 
    You are trying to get Tewkesbury to the House of Lords in time for the vote. 
    However, the police is following you and sometimes you need to quickly hide.

    When you see 'POLICE', you have 0.4 seconds to hide by pressing Enter.
    """)
    print()
    input(prompt="Press Enter to begin...")

    while True:
        print()
        print("You are trying to run away...")
        #The time it takes until police is printed is randomized
        time.sleep(random.randint(20,50)/10.0)
        print("POLICE!")
        drawTime=time.time()
        #This function call doesn't return until Enter is pressed 
        input(prompt="")
        timeElapsed = time.time() - drawTime

        #callreturns almost instantly, seems like someone is cheating
        if timeElapsed <0.03: 
            print("You hid before 'POLICE!'appeared! You lose.")
            return fail()
            break
        
        #fast but possible time to press enter/ hide
        elif timeElapsed >0.4:
            timeElapsed = round (timeElapsed, 4)
            print("You took", timeElapsed, "seconds to hide. Too slow.")
        
        #you were fast enough to hide in time, you win, loop breaks 
        else:
            timeElapsed = round(timeElapsed, 4)
            print("You took", timeElapsed, "seconds to hide.")
            print("You were able to lose the police! You win!")
            break

        #if you don't want to continue trying this gives you a way out, however you will lose
        print ("Enter QUIT to stop, or press Enter to play again.")
        response = input (prompt=">").upper()
        if response == "QUIT":
            print ("Thanks for playing!")
            return fail()
            break
    
    #message to the user that they won the game 
    list=['superstar', 'hero', 'celebrity', 'lion']
    superstar=random.choice(list) 
    print (f"""
    **************************************************************************
    
    Congratulations!! You won the game. You are a {superstar}! 
    Tewkesbury was able to claim his righful seat in the House of Lords.
    He voted in favor of the female revolution. 
    
    **************************************************************************
    
    """)
    
    restart=input(prompt="Do you want to restart? (Yes/No) ")
    return "restart" if "yes" in restart.lower().strip() else "Thank you for playing"


def fail():
    print("You've failed, but thanks for playing!")
    restart=input(prompt="Do you want to restart? ")
    return "restart" if "yes" in restart.lower().strip() else "Thank you for playing"   
        

#This is the heart of the game
#every escape produces an output
#This leads the user either to the next part of the journey or back to the start
while True:
    escape_1_state = escape_1()
    if escape_1_state not in ["restart", "exit", "continue"]:
        break
    else:
        if escape_1_state == "restart":
            continue
        
        elif escape_1_state == "exit":
            break
        
    escape_2_state = escape_2()
    if escape_2_state not in ["restart", "exit", "continue"]:
        break
    else:
        if escape_2_state == "restart":
            continue
        
        elif escape_2_state == "exit":
            break
    
    escape_3_state = escape_3()
    if escape_3_state not in ["restart", "exit", "continue"]:
        break
    else:
        if escape_3_state == "restart":
            continue
        
        elif escape_3_state == "exit":
            break
    
    
 
    break
    

#Detailed sources
#Chase Kusterer, Hult Business School, Book: Python for Business Analytics & according in class scripts
#AL Sweigart, THE BIG BOOK OF SMALL PYTHON PROJECT, retrieved from: https://edu.anarcho-copy.org/Programming%20Languages/Python/BigBookSmallPythonProjects.pdf 
#AsciiART Maze, retrieved from: https://www.asciiart.eu/art-and-design/mazes
# Out:
#
#
#     United Kingdom, 1900
#     This is your story,
#     the story of Enola Holmes, the sister of Sherlock Holmes.
#     You are 15 years younger than Sherlock and only grew up with your mother.
#     She raised you to be an independent woman, able to decipher, do jiujitsu,
#     and just like Sherlock, solve mysteries.
#     On your 16th birthday you find out that you were left by your mother.
#     Your brothers are trying to send you to a boarding school.
#     A school meant for you to be turned into the perfect wife.
#     However, you don't agree with their plans and escape.
#
#
# Do you want to go on this journey? (Yes/No): yes
#
# Enola you can either take your bike or the train to escape.
# What do you choose? (Bike/Train): train
# Great, you successfully escaped and are on the train.
#
# On the train you meet Viscount Tewkesbury Marquess of Basilwether.
# You challenge him to decipher your final destination:
#
# 	'odLnno'
#
# What is the final destination?:  london
#
# ...
